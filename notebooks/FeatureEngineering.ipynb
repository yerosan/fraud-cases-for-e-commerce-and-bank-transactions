# %% [markdown]
# ## Feature Engineering
# Created additional features to enhance model performance:
# - **Transaction Frequency:** Tracks the number of transactions over a specific period.
# - **Time-related Features:** Includes features like the hour of the day and day of the week.
# - **IP-based Geolocation Information:** Extracts geolocation data based on IP addresses to identify potential fraud patterns.

# %%
import os
import sys

sys.path.insert(0,os.path.dirname(os.getcwd()))

# %%
from scripts import featureEnginerring

# %%
import pandas as pd
fraudData=pd.read_csv("../Data/Merged_cleanData.csv")

# %%
feature_engineering=featureEnginerring.FeatureEngineer(fraudData)

# %%
feature_engineering.create_time_features()

# %%
feature_engineering.transaction_frequency()

# %%
feature_engineering.normalize_and_scale()

# %%
feature_engineering.encode_categorical_features()

# %%
featuredData=feature_engineering.get_feature_data()

# %%
featuredData.head()
# Out:
#    Unnamed: 0  purchase_value       age  ip_address  class  signup_hour  \
# 0           0       -0.160088  0.681533   732758368      0           22
# 1           1       -1.142743  2.306556   350311387      0           20
# 2           2       -1.197335  2.306556  2621473820      1           18
# 4           4        0.112871  1.377971   415583117      0            7
# 5           5        0.276647 -1.756001  2809315199      0            6
#
#    purchase_hour  signup_day  purchase_day  hour_of_day  day_of_week  \
# 0              2           1             5            2            5
# 1              1           6             0            1            0
# 2             18           3             3           18            3
# 4             18           1             2           18            2
# 5              8           3             3            8            3
#
#    country_encoded  transaction_count  source_Direct  source_SEO  \
# 0         0.097865                0.0          False        True
# 1         0.095626                0.0          False       False
# 2         0.095626                0.0          False        True
# 4         0.095626                0.0          False       False
# 5         0.116975                0.0          False       False
#
#    browser_FireFox  browser_IE  browser_Opera  browser_Safari  sex_M
# 0            False       False          False           False   True
# 1            False       False          False           False  False
# 2            False       False           True           False   True
# 4            False       False          False            True   True
# 5            False       False          False           False   True

# %%
featuredData.dtypes
# Out:
# Unnamed: 0             int64
# purchase_value       float64
# age                  float64
# ip_address             int64
# class                  int64
# signup_hour            int64
# purchase_hour          int64
# signup_day             int64
# purchase_day           int64
# hour_of_day            int32
# day_of_week            int32
# country_encoded      float64
# transaction_count    float64
# source_Direct           bool
# source_SEO              bool
# browser_FireFox         bool
# browser_IE              bool
# browser_Opera           bool
# browser_Safari          bool
# sex_M                   bool
# dtype: object

# %%
featuredData.isnull()
# Out:
#         Unnamed: 0  purchase_value    age  ip_address  class  signup_hour  \
# 0            False           False  False       False  False        False
# 1            False           False  False       False  False        False
# 2            False           False  False       False  False        False
# 4            False           False  False       False  False        False
# 5            False           False  False       False  False        False
# ...            ...             ...    ...         ...    ...          ...
# 151106       False           False  False       False  False        False
# 151107       False           False  False       False  False        False
# 151108       False           False  False       False  False        False
# 151109       False           False  False       False  False        False
# 151110       False           False  False       False  False        False
#
#         purchase_hour  signup_day  purchase_day  hour_of_day  day_of_week  \
# 0               False       False         False        False        False
# 1               False       False         False        False        False
# 2               False       False         False        False        False
# 4               False       False         False        False        False
# 5               False       False         False        False        False
# ...               ...         ...           ...          ...          ...
# 151106          False       False         False        False        False
# 151107          False       False         False        False        False
# 151108          False       False         False        False        False
# 151109          False       False         False        False        False
# 151110          False       False         False        False        False
#
#         country_encoded  transaction_count  source_Direct  source_SEO  \
# 0                 False              False          False       False
# 1                 False              False          False       False
# 2                 False              False          False       False
# 4                 False              False          False       False
# 5                 False              False          False       False
# ...                 ...                ...            ...         ...
# 151106            False              False          False       False
# 151107            False              False          False       False
# 151108            False              False          False       False
# 151109            False              False          False       False
# 151110            False              False          False       False
#
#         browser_FireFox  browser_IE  browser_Opera  browser_Safari  sex_M
# 0                 False       False          False           False  False
# 1                 False       False          False           False  False
# 2                 False       False          False           False  False
# 4                 False       False          False           False  False
# 5                 False       False          False           False  False
# ...                 ...         ...            ...             ...    ...
# 151106            False       False          False           False  False
# 151107            False       False          False           False  False
# 151108            False       False          False           False  False
# 151109            False       False          False           False  False
# 151110            False       False          False           False  False
#
# [129146 rows x 20 columns]

# %%
featuredData.to_csv("../Data/featuredData.csv")
